# %%
# Import Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_hub as hub
from IPython.display import Image
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, load_img
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import os
import zipfile
import random
import datetime
import shutil
from sklearn.metrics import confusion_matrix
import seaborn as sns
import datetime
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install rarfile
import rarfile
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# <= Click this cell to rar the folder

# !apt-get install rar
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   rar
# 0 upgraded, 1 newly installed, 0 to remove and 42 not upgraded.
# Need to get 295 kB of archives.
# After this operation, 799 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 rar amd64 2:5.5.0-1 [295 kB]
# Fetched 295 kB in 1s (563 kB/s)
# Selecting previously unselected package rar.
# (Reading database ... 155629 files and directories currently installed.)
# Preparing to unpack .../rar_2%3a5.5.0-1_amd64.deb ...
# Unpacking rar (2:5.5.0-1) ...
# Setting up rar (2:5.5.0-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
database_file1 = '/content/drive/MyDrive/datasetbr/datasetbaru.rar'
data_file1 = rarfile.RarFile(database_file1, 'r')
data_file1.extractall()
data_file1.close()

# %%
from google.colab import files

# %%
# make augmentation directory for the results
# !mkdir '/content/drive/MyDrive/datasetbr/augmented'
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/datasetbr/augmented’: File exists

# %%
# take 20 data per label

TRAINING_IMAGE_PATH = []
TRAINING_LABEL = []


# Akar Manis
akarmanis_train_list = ['/content/datasetbaru/akarmanis']

for index in range(len(akarmanis_train_list)):
    for num_image, image in enumerate(os.listdir(akarmanis_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(akarmanis_train_list[index], image))

# Akar Manis label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("akarmanis (1)")


# Daun Jambu Mete
daunjambumete_train_list = ['/content/datasetbaru/daunjambumete']

for index in range(len(daunjambumete_train_list)):
    for num_image, image in enumerate(os.listdir(daunjambumete_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(daunjambumete_train_list[index], image))

# Daun Jambu Mete label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("daunjambumete (1)")


# Jahe
Jahe_train_list = ['/content/datasetbaru/Jahe']

for index in range(len(Jahe_train_list)):
    for num_image, image in enumerate(os.listdir(Jahe_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(Jahe_train_list[index], image))

# Jahe label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("jahe (1)")


# Jinten
Jinten_train_list = ['/content/datasetbaru/Jinten']

for index in range(len(Jinten_train_list)):
    for num_image, image in enumerate(os.listdir(Jinten_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(Jinten_train_list[index], image))

# Jinten label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("Jinten (1)")


# Kapulaga
Kapulaga_train_list = ['/content/datasetbaru/Kapulaga']

for index in range(len(Kapulaga_train_list)):
    for num_image, image in enumerate(os.listdir(Kapulaga_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(Kapulaga_train_list[index], image))

# Kapulaga label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("Kapulaga (1)")

    
# Kunyit
Kunyit_train_list = ['/content/datasetbaru/Kunyit']

for index in range(len(Kunyit_train_list)):
    for num_image, image in enumerate(os.listdir(Kunyit_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(Kunyit_train_list[index], image))

# Kunyit label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("kunyit (1)")


# Lidah Buaya
lidahbuaya_train_list = ['/content/datasetbaru/lidahbuaya']

for index in range(len(lidahbuaya_train_list)):
    for num_image, image in enumerate(os.listdir(lidahbuaya_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(lidahbuaya_train_list[index], image))

# Lidah Buaya label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("lidahbuaya (1)")


# Mengkudu
Mengkudu_train_list = ['/content/datasetbaru/Mengkudu']

for index in range(len(Mengkudu_train_list)):
    for num_image, image in enumerate(os.listdir(Mengkudu_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(Mengkudu_train_list[index], image))

# Mengkudu label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("mengkudu (1)")


# Meniran
Meniran_train_list = ['/content/datasetbaru/Meniran']

for index in range(len(Meniran_train_list)):
    for num_image, image in enumerate(os.listdir(Meniran_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(Meniran_train_list[index], image))

# Meniran label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("meniran (1)")


# Purwoceng
Purwoceng_train_list = ['/content/datasetbaru/Purwoceng']

for index in range(len(Purwoceng_train_list)):
    for num_image, image in enumerate(os.listdir(Purwoceng_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(Purwoceng_train_list[index], image))

# Purwoceng label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("purwoceng (1)")


# Sambiloto
Sambiloto_train_list = ['/content/datasetbaru/Sambiloto']

for index in range(len(Sambiloto_train_list)):
    for num_image, image in enumerate(os.listdir(Sambiloto_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(Sambiloto_train_list[index], image))

# Sambiloto label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("sambiloto (1)")


# Sereh
Sereh_train_list = ['/content/datasetbaru/Sereh']

for index in range(len(Sereh_train_list)):
    for num_image, image in enumerate(os.listdir(Sereh_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(Sereh_train_list[index], image))

# Sereh label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("sereh (1)")


# Temulawak
Temulawak_train_list = ['/content/datasetbaru/Temulawak']

for index in range(len(Temulawak_train_list)):
    for num_image, image in enumerate(os.listdir(Temulawak_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(Temulawak_train_list[index], image))

# Temulawak label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("temulawak (1)")


# Daun Kelor
daunkelor_train_list = ['/content/datasetbaru/daunkelor']

for index in range(len(daunkelor_train_list)):
    for num_image, image in enumerate(os.listdir(daunkelor_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(daunkelor_train_list[index], image))

# Daun Kelor label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("daunkelor (1)")


# Daun Kemangi
daunkemangi_train_list = ['/content/datasetbaru/daunkemangi']

for index in range(len(daunkemangi_train_list)):
    for num_image, image in enumerate(os.listdir(daunkemangi_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(daunkemangi_train_list[index], image))

# Daun Kemangi label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("daunkemangi (1)")


# Daun Sirih
daunsirih_train_list = ['/content/datasetbaru/daunsirih']

for index in range(len(daunsirih_train_list)):
    for num_image, image in enumerate(os.listdir(daunsirih_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(daunsirih_train_list[index], image))

# Daun Sirih label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("daunsirih (1)")


# Kayu Manis
kayumanis_train_list = ['/content/datasetbaru/kayumanis']

for index in range(len(kayumanis_train_list)):
    for num_image, image in enumerate(os.listdir(kayumanis_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(kayumanis_train_list[index], image))

# Kayu Manis label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("kayumanis (1)")


# Kencur
Kencur_train_list = ['/content/datasetbaru/Kencur']

for index in range(len(Kencur_train_list)):
    for num_image, image in enumerate(os.listdir(Kencur_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(Kencur_train_list[index], image))

# Kencur label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("kencur (1)")


# Kumis Kucing
kumiskucing_train_list = ['/content/datasetbaru/kumiskucing']

for index in range(len(kumiskucing_train_list)):
    for num_image, image in enumerate(os.listdir(kumiskucing_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(kumiskucing_train_list[index], image))

# Kumis Kucing label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("kumiskucing (1)")


# Lengkuas
lengkuas_train_list = ['/content/datasetbaru/lengkuas']

for index in range(len(lengkuas_train_list)):
    for num_image, image in enumerate(os.listdir(lengkuas_train_list[index])):
        if num_image < 100:  # hanya ambil 100 data
            TRAINING_IMAGE_PATH.append(os.path.join(lengkuas_train_list[index], image))

# Lengkuas label (hanya ambil 100 data)
for i in range(100):
    TRAINING_LABEL.append("lengkuas (1)")

# %%
# Check jumlah image, jumlah label TRAINING

print(len(TRAINING_IMAGE_PATH), len(TRAINING_LABEL))
# Out:
# 2000 2000

# %%
# take 20 data per label untuk validation set

VALIDATION_IMAGE_PATH = []
VALIDATION_LABEL = []


# Akar Manis
akarmanis_train_list = ['/content/datasetbaru/akarmanis']

for index in range(len(akarmanis_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(akarmanis_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(akarmanis_train_list[index], image))

# Akar Manis Label
for i in range(100):
    VALIDATION_LABEL.append("akarmanis (1)")


# Daun Jambu Mete
daunjambumete_train_list = ['/content/datasetbaru/daunjambumete']

for index in range(len(daunjambumete_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(daunjambumete_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(daunjambumete_train_list[index], image))

# Daun Jambu Mete Label
for i in range(100):
    VALIDATION_LABEL.append("daunjambumete (1)")


# Jahe
Jahe_train_list = ['/content/datasetbaru/Jahe']

for index in range(len(Jahe_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(Jahe_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(Jahe_train_list[index], image))

# Jahe Label
for i in range(100):
    VALIDATION_LABEL.append("jahe (1)")


# Jinten
Jinten_train_list = ['/content/datasetbaru/Jinten']

for index in range(len(Jinten_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(Jinten_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(Jinten_train_list[index], image))

# Jinten Label
for i in range(100):
    VALIDATION_LABEL.append("Jinten (1)")


# Kapulaga
Kapulaga_train_list = ['/content/datasetbaru/Kapulaga']

for index in range(len(Kapulaga_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(Kapulaga_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(Kapulaga_train_list[index], image))

# Kapulaga Label
for i in range(100):
    VALIDATION_LABEL.append("Kapulaga (1)")


# Kunyit
Kunyit_train_list = ['/content/datasetbaru/Kunyit']

for index in range(len(Kunyit_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(Kunyit_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(Kunyit_train_list[index], image))

# Kunyit Label
for i in range(100):
    VALIDATION_LABEL.append("kunyit (1)")


# Lidah Buaya
lidahbuaya_train_list = ['/content/datasetbaru/lidahbuaya']

for index in range(len(lidahbuaya_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(lidahbuaya_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(lidahbuaya_train_list[index], image))

# Lidah Buaya Label
for i in range(100):
    VALIDATION_LABEL.append("lidahbuaya (1)")


# Mengkudu
Mengkudu_train_list = ['/content/datasetbaru/Mengkudu']

for index in range(len(Mengkudu_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(Mengkudu_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(Mengkudu_train_list[index], image))

# Mengkudu Label
for i in range(100):
    VALIDATION_LABEL.append("mengkudu (1)")


# Meniran
Meniran_train_list = ['/content/datasetbaru/Meniran']

for index in range(len(Meniran_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(Meniran_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(Meniran_train_list[index], image))

# Meniran Label
for i in range(100):
    VALIDATION_LABEL.append("meniran (1)")


# Purwoceng
Purwoceng_train_list = ['/content/datasetbaru/Purwoceng']

for index in range(len(Purwoceng_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(Purwoceng_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(Purwoceng_train_list[index], image))

# Purwoceng Label
for i in range(100):
    VALIDATION_LABEL.append("purwoceng (1)")


# Sambiloto
Sambiloto_train_list = ['/content/datasetbaru/Sambiloto']

for index in range(len(Sambiloto_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(Sambiloto_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(Sambiloto_train_list[index], image))

# Sambiloto Label
for i in range(100):
    VALIDATION_LABEL.append("sambiloto (1)")


# Sereh
Sereh_train_list = ['/content/datasetbaru/Sereh']

for index in range(len(Sereh_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(Sereh_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(Sereh_train_list[index], image))

# Sereh Label
for i in range(100):
    VALIDATION_LABEL.append("sereh (1)")


# Temulawak
Temulawak_train_list = ['/content/datasetbaru/Temulawak']

for index in range(len(Temulawak_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(Temulawak_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(Temulawak_train_list[index], image))

# Temulawak Label
for i in range(100):
    VALIDATION_LABEL.append("temulawak (1)")


# Daun Kelor
daunkelor_train_list = ['/content/datasetbaru/daunkelor']

for index in range(len(daunkelor_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(daunkelor_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(daunkelor_train_list[index], image))

# Daun Kelor Label
for i in range(100):
    VALIDATION_LABEL.append("daunkelor (1)")


# Daun Kemangi
daunkemangi_train_list = ['/content/datasetbaru/daunkemangi']

for index in range(len(daunkemangi_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(daunkemangi_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(daunkemangi_train_list[index], image))

# Daun Kemangi Label
for i in range(100):
    VALIDATION_LABEL.append("daunkemangi (1)")


# Daun Sirih
daunsirih_train_list = ['/content/datasetbaru/daunsirih']

for index in range(len(daunsirih_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(daunsirih_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(daunsirih_train_list[index], image))

# Daun Sirih Label
for i in range(100):
    VALIDATION_LABEL.append("daunsirih (1)")


# Kayu Manis
kayumanis_train_list = ['/content/datasetbaru/kayumanis']

for index in range(len(kayumanis_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(kayumanis_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(kayumanis_train_list[index], image))

# Kayu Manis Label
for i in range(100):
    VALIDATION_LABEL.append("kayumanis (1)")


# Kencur
kencur_train_list = ['/content/datasetbaru/Kencur']

for index in range(len(Kencur_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(Kencur_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(Kencur_train_list[index], image))

# Kencur Label
for i in range(100):
    VALIDATION_LABEL.append("kencur (1)")


# Kumis Kucing
kumiskucing_train_list = ['/content/datasetbaru/kumiskucing']

for index in range(len(kumiskucing_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(kumiskucing_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(kumiskucing_train_list[index], image))

# Kumis Kucing Label
for i in range(100):
    VALIDATION_LABEL.append("kumiskucing (1)")


# Lengkuas
lengkuas_train_list = ['/content/datasetbaru/lengkuas']

for index in range(len(lengkuas_train_list)):
    if index == 0:
        for num_image, image in enumerate(os.listdir(lengkuas_train_list[index])):
            if 0 <= num_image < 100:
                VALIDATION_IMAGE_PATH.append(os.path.join(lengkuas_train_list[index], image))

# Lengkuas Label
for i in range(100):
    VALIDATION_LABEL.append("lengkuas (1)")

# %%
# Check jumlah image, jumlah label VALIDATION

print(len(VALIDATION_IMAGE_PATH), len(VALIDATION_LABEL))
# Out:
# 2000 2000

# %% [markdown]
# ## 1. Import Data

# %% [markdown]
# TRAINING DATASET

# %%
database_train = pd.DataFrame(TRAINING_IMAGE_PATH, columns=['path'])
database_train['label'] = TRAINING_LABEL

database_train.head()
# Out:
#                                                 path          label
# 0  /content/datasetbaru/akarmanis/akarmanis (21).png  akarmanis (1)
# 1  /content/datasetbaru/akarmanis/akarmanis (74).png  akarmanis (1)
# 2  /content/datasetbaru/akarmanis/akarmanis (83).png  akarmanis (1)
# 3   /content/datasetbaru/akarmanis/akarmanis (3).png  akarmanis (1)
# 4  /content/datasetbaru/akarmanis/akarmanis (64).png  akarmanis (1)

# %%
print (database_train)
# Out:
#                                                    path          label
# 0     /content/datasetbaru/akarmanis/akarmanis (21).png  akarmanis (1)
# 1     /content/datasetbaru/akarmanis/akarmanis (74).png  akarmanis (1)
# 2     /content/datasetbaru/akarmanis/akarmanis (83).png  akarmanis (1)
# 3      /content/datasetbaru/akarmanis/akarmanis (3).png  akarmanis (1)
# 4     /content/datasetbaru/akarmanis/akarmanis (64).png  akarmanis (1)
# ...                                                 ...            ...
# 1995    /content/datasetbaru/lengkuas/lengkuas (95).png   lengkuas (1)
# 1996    /content/datasetbaru/lengkuas/lengkuas (59).png   lengkuas (1)
# 1997    /content/datasetbaru/lengkuas/lengkuas (80).png   lengkuas (1)
# 1998    /content/datasetbaru/lengkuas/lengkuas (76).png   lengkuas (1)
# 1999    /content/datasetbaru/lengkuas/lengkuas (27).png   lengkuas (1)
#
# [2000 rows x 2 columns]

# %% [markdown]
# VALIDATION DATASET

# %%
database_val = pd.DataFrame(VALIDATION_IMAGE_PATH, columns=['path'])
database_val['label'] = VALIDATION_LABEL

database_val.head()
# Out:
#                                                 path          label
# 0  /content/datasetbaru/akarmanis/akarmanis (21).png  akarmanis (1)
# 1  /content/datasetbaru/akarmanis/akarmanis (74).png  akarmanis (1)
# 2  /content/datasetbaru/akarmanis/akarmanis (83).png  akarmanis (1)
# 3   /content/datasetbaru/akarmanis/akarmanis (3).png  akarmanis (1)
# 4  /content/datasetbaru/akarmanis/akarmanis (64).png  akarmanis (1)

# %%
# unique labels

unique_label = np.array(database_train['label'].unique())
unique_label
# Out:
# array(['akarmanis (1)', 'daunjambumete (1)', 'jahe (1)', 'Jinten (1)',
#        'Kapulaga (1)', 'kunyit (1)', 'lidahbuaya (1)', 'mengkudu (1)',
#        'meniran (1)', 'purwoceng (1)', 'sambiloto (1)', 'sereh (1)',
#        'temulawak (1)', 'daunkelor (1)', 'daunkemangi (1)',
#        'daunsirih (1)', 'kayumanis (1)', 'kencur (1)', 'kumiskucing (1)',
#        'lengkuas (1)'], dtype=object)

# %%
# num unique labels

num_unique_label = len(unique_label)
num_unique_label
# Out:
# 20

# %%
# Encoding labels
# Turns into boolean array for all index

# train
boolean_array = [database_train['label'][i] == unique_label for i in range(len(database_train))]

# validation
boolean_array_val = [database_val['label'][i] == unique_label for i in range(len(database_val))]

# %%
# check boolean array for data in index 0

boolean_array[0]
# Out:
# array([ True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %% [markdown]
# TURN DATA INTO SET

# %% [markdown]
# - DEFINE X_train, y_train, X_val, y_val

# %%
# train
X_train = database_train['path']
y_train = boolean_array

# validation
X_val = database_val['path']
y_val = boolean_array_val

# %% [markdown]
# - TURN INTO TENSOR SETS

# %%
# train
train_set = tf.data.Dataset.from_tensor_slices(( tf.constant(X_train), tf.constant(y_train) ))

# validation
val_set = tf.data.Dataset.from_tensor_slices(( tf.constant(X_val), tf.constant(y_val) ))

# %% [markdown]
# 4. SHUFFLING TRAINING SET

# %%
BUFFER_SIZE = len(train_set)

train_set = train_set.shuffle(BUFFER_SIZE)

# %% [markdown]
# 04. **PREPROCESS DATA**

# %% [markdown]
# ## 1. Preprocess Image
#
# Turn image into numbers, normalize pixel values, resize shape of the image

# %%
# our desired image size
IMAGE_SIZE = 224

# read, turn image into number, normalize, resize
def preprocess_image(image_path, labels=None):
    # read image
    image = tf.io.read_file(image_path)
    # turn jpeg into numbers
    image = tf.image.decode_jpeg(image, channels=3)
    # scaling / normalize (0,255) menjadi (0,1)
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    # resize to (224,224)
    image = tf.image.resize(image, size=[IMAGE_SIZE, IMAGE_SIZE])
    # return
    return image, labels

# %%
# apply

train_set = train_set.map(preprocess_image)
val_set = val_set.map(preprocess_image)

# %% [markdown]
# ## 2. Batching

# %%
# batch size
BATCH_SIZE = 32

# batching train & validation set
train_set = train_set.batch(BATCH_SIZE)
val_set = val_set.batch(BATCH_SIZE)

# %%
# check element spec

train_set.element_spec
# Out:
# (TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 20), dtype=tf.bool, name=None))

# %% [markdown]
# # **05. Show Images (Optional)**
#
# Show images and their label in one batch (32 images)

# %%
def show_images_in_a_batch(images, labels):
    # create a figure
    plt.figure(figsize=(15, 15))

    # for each image in one batch (32 images)
    for i in range(32):

        # Create subplots (8 rows, 5 columns)
        ax = plt.subplot(8, 5, i+1)  # i = index

        # Show the image 
        plt.imshow(images[i])

        # Add the image label as the title
        plt.title(unique_label[np.argmax(labels[i])])

        # Turn the grid lines off
        plt.axis("off")

# %%
# take one random batch from training set
sample_train_images, sample_train_labels = next(iter(train_set))

# show
show_images_in_a_batch(sample_train_images, sample_train_labels)

# %% [markdown]
# # **06. Build Tranfer Learning Model**
#
# With ResNet50 model https://tfhub.dev/tensorflow/resnet_50/feature_vector/1

# %% [markdown]
# ## 1. Create Model

# %%
model = tf.keras.Sequential([
                             # transfer learning model
                             hub.KerasLayer("https://tfhub.dev/tensorflow/resnet_50/feature_vector/1"),
                             
                             # output layer
                             tf.keras.layers.Dense(units=num_unique_label, activation='softmax')
])

# %% [markdown]
# ## 2. Compile Model

# %%
# compile
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# build the model and pass the input shape
model.build(input_shape = [None, 224, 224, 3])

# %% [markdown]
# ## 3. Create Callback

# %%
# EARLYSTOPPING CALLBACK
# monitor the val loss (prevent overfitting)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

# %%
# CUSTOM CALLBACK
# stop training once training accuracy reaches 99.0%

class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.99):
      print("\nReached 99.0% accuracy stop training!")
      self.model.stop_training = True

# create accuracy_callback and call myCallback class
accuracy_callback = myCallback()

# %% [markdown]
# ## 4. Training Model

# %%
history_train = model.fit(train_set, epochs=50,
                          validation_data = val_set,
                          callbacks=[early_stopping, accuracy_callback])
# Out:
# Epoch 1/50
# 63/63 [==============================] - 47s 407ms/step - loss: 1.4694 - accuracy: 0.5780 - val_loss: 0.6051 - val_accuracy: 0.8350
# Epoch 2/50
# 63/63 [==============================] - 24s 387ms/step - loss: 0.5422 - accuracy: 0.8435 - val_loss: 0.3595 - val_accuracy: 0.9115
# Epoch 3/50
# 63/63 [==============================] - 32s 518ms/step - loss: 0.3548 - accuracy: 0.9090 - val_loss: 0.2542 - val_accuracy: 0.9495
# Epoch 4/50
# 63/63 [==============================] - 24s 389ms/step - loss: 0.2547 - accuracy: 0.9415 - val_loss: 0.1907 - val_accuracy: 0.9640
# Epoch 5/50
# 63/63 [==============================] - 33s 524ms/step - loss: 0.1923 - accuracy: 0.9605 - val_loss: 0.1507 - val_accuracy: 0.9765
# Epoch 6/50
# 63/63 [==============================] - 23s 368ms/step - loss: 0.1536 - accuracy: 0.9735 - val_loss: 0.1235 - val_accuracy: 0.9800
# Epoch 7/50
# ...

# %% [markdown]
# ## 5. Save Model

# %%
import keras
from keras.models import load_model

model.save('model_resnet50_new.h5')

# %% [markdown]
# # **07. Accuracy & Loss**

# %%
# train
acc = history_train.history['accuracy']
loss = history_train.history['loss']

# validation
val_acc = history_train.history['val_accuracy']
val_loss = history_train.history['val_loss']

# range number of epochs
epochs = range(len(acc))

# plot training and validation accuracy per epoch
plt.plot(epochs, acc)
plt.plot(epochs, val_acc)
plt.title ('Training and validation accuracy')
plt.figure()

# plot training and validation loss per epoch
plt.plot(epochs, loss)
plt.plot(epochs, val_loss)
plt.title ('Training and validation loss')

plt.legend(['train', 'val'])

# %% [markdown]
# # **08.Testing**

# %%
# upload files
uploaded=files.upload()

filename = []
test_images = []

for fn in uploaded.keys():
    filename.append(fn)
    path='/content/' + fn
    test_images.append(path)

# turn into set
test_set = tf.data.Dataset.from_tensor_slices(( tf.constant(test_images) ))

# preprocess
test_set = test_set.map(preprocess_image)

# batching
test_set = test_set.batch(batch_size=32)

# predict
test_predictions = model.predict(test_set)

label_prediction = []
for i in range(len(test_predictions)):
    label_prediction.append(unique_label[np.argmax(test_predictions[i])])

# show prediction results
for i in range(len(test_images)):
    print(label_prediction[i])
    pil_img = Image(filename=test_images[i], width=150, height=150)
    display(pil_img)
# Out:
#      <input type="file" id="files-5ad89686-869e-402d-923d-92e5b9a903e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ad89686-869e-402d-923d-92e5b9a903e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving daunkelor (12).png to daunkelor (12).png
# daunkelor (1)
